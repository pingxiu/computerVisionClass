# %%
import cv2
import numpy as np
import matplotlib.pyplot as pl

# %%
# Read source image.
im_src = cv2.imread('dsu1.jpg')
# Four corners of the book in source image
pts_src = np.array([[324, 281], [326, 538] ,[760, 318],[768, 508]])
# pts_dst = np.array([[179, 245], [179, 505] ,[820, 220],[820, 520]])
# Read destination image.
im_dst = cv2.imread('dsu2.jpg')
# Four corners of the book in destination image.
# pts_src = np.array([[324, 281], [326, 538] ,[760, 318],[768, 508]])
pts_dst = np.array([[179, 245], [179, 505] ,[820, 220],[820, 520]])
# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)
# Warp source image to destination based on homography
im_out = cv2.warpPerspective(im_src, h, (im_dst.shape[1],im_dst.shape[0]))
# Display images
pl.imshow(cv2.cvtColor(im_src, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_dst, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_out, cv2.COLOR_BGR2RGB))
pl.show()

# %%
# Read source image.
im_src = cv2.imread('dsu3.jpg')
# Four corners of the book in source image
pts_src = np.array([[103, 230], [110, 500],[698, 161] ,[703, 532]])
# Read destination image.
im_dst = cv2.imread('dsu2.jpg')
# Four corners of the book in destination image.
pts_dst = np.array([[179, 245], [179, 505] ,[820, 220],[820, 520]])
# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)
# Warp source image to destination based on homography
im_out = cv2.warpPerspective(im_src, h, (im_dst.shape[1],im_dst.shape[0]))
# Display images
pl.imshow(cv2.cvtColor(im_src, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_dst, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_out, cv2.COLOR_BGR2RGB))
pl.show()

# %%
# Read source image.
im_src = cv2.imread('dsu4.jpg')
# Four corners of the book in source image
pts_src = np.array([[239, 270], [237, 460],[567, 239] ,[564, 497]])
# Read destination image.
im_dst = cv2.imread('dsu2.jpg')
# Four corners of the book in destination image.
pts_dst = np.array([[179, 245], [179, 505] ,[820, 220],[820, 520]])
# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)
# Warp source image to destination based on homography
im_out = cv2.warpPerspective(im_src, h, (im_dst.shape[1],im_dst.shape[0]))
# Display images
pl.imshow(cv2.cvtColor(im_src, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_dst, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_out, cv2.COLOR_BGR2RGB))
pl.show()

# %%
# Read source image.
im_src = cv2.imread('dsu5.jpg')
# Four corners of the book in source image
pts_src = np.array([[569, 283], [576, 301],[679, 318] ,[683, 329]])
# Read destination image.
im_dst = cv2.imread('dsu6.jpg')
# Four corners of the book in destination image.
pts_dst = np.array([[451, 262], [455, 284] ,[618, 286],[618, 300]])
# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)
# Warp source image to destination based on homography
im_out = cv2.warpPerspective(im_src, h, (im_dst.shape[1],im_dst.shape[0]))
# Display images
pl.imshow(cv2.cvtColor(im_src, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_dst, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_out, cv2.COLOR_BGR2RGB))
pl.show()

# %%
# Read source image.
im_src = cv2.imread('dsu7.jpg')
# Four corners of the book in source image
pts_src = np.array([[297, 292], [293, 365],[590, 274] ,[590, 360]])
# Read destination image.
im_dst = cv2.imread('dsu8.jpg')
# Four corners of the book in destination image.
pts_dst = np.array([[183, 300], [178, 385] ,[559, 297],[563, 393]])
# Calculate Homography
h, status = cv2.findHomography(pts_src, pts_dst)
# Warp source image to destination based on homography
im_out = cv2.warpPerspective(im_src, h, (im_dst.shape[1],im_dst.shape[0]))
# Display images
pl.imshow(cv2.cvtColor(im_src, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_dst, cv2.COLOR_BGR2RGB))
pl.show()
pl.imshow(cv2.cvtColor(im_out, cv2.COLOR_BGR2RGB))
pl.show()
